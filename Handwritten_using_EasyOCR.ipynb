# %%
from IPython.display import clear_output
# !pip install keras-ocr
import keras_ocr
clear_output()

# %%
# !pip install easyocr
# !pip install pytesseract
import pytesseract
import keras_ocr
import easyocr
import matplotlib.pyplot as plt
import cv2,os
# %matplotlib inline
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.3/281.3 kB 15.2 MB/s eta 0:00:00
# ...

# %%
text_reader=easyocr.Reader(['en'])
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...

# %%
images="/content/ocr1.jpeg"
results = text_reader.readtext(images)
for (bbox, text, prob) in results:
    print(text)
img = cv2.imread(images)
plt.imshow(img)
plt.title("First Image");
# Out:
# Cedric
# himself
# knew
# nothing
# whatever   about it:
# It   had
# never  been
# even mentioned
# him  He knew that
# his
# papa
# had
# been
# Englishman_
# because his mamma had told him
# SO;
# but
# then  his papa had died when
# he
# was
# little
# that he could
# nol
# remember
# very
# much
# about
# him;
# except that
# was
# big;
# and had blue
# eyes and
# mustache
# and that It
# was
# splendid
# be
# carried
# around
# the
# room
# his
# shoulder:
# boy
# long
# thing

# %%
images="/content/ocr2.jpeg"
results = text_reader.readtext(images)
for (bbox, text, prob) in results:
    print(text)
# read the image data using cv2.imread
img = cv2.imread(images)
plt.imshow(img)
plt.title("First Image");
# Out:
# This is a lot of 12 point text to test
# ocr code and see if it works on all
# of file format
# The quick brown
# jumped over
# lazy fox. The quick brown dog jump
# over the lazy
# quick brown
# jumped over the lazy fox. The quic
# brown
# jumped over the lazy fo
# dog
# fox
# The
# dog

# %%
images="/content/ocr3.jpeg"
results = text_reader.readtext(images)
for (bbox, text, prob) in results:
    print(text)
# read the image data using cv2.imread
img = cv2.imread(images)
plt.imshow(img)
plt.title("First Image");
# Out:
# ABCDEFGHIJKLMN
# OPQRSTUVUXYZ
# abcdefghi jklmn
# opqrstuvwxyz
# 1234567890!?&
